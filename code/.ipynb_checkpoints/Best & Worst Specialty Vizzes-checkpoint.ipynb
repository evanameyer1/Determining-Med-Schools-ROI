# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
main = pd.read_csv('../updated datasources/specialty_totals.csv')

# %%
main
# Out:
#     specialty_id                             specialty  compensation_score  \
# 0              5                           Dermatology                  28
# 1             21                       Plastic Surgery                  17
# 2             22                            Psychiatry                  18
# 3             11                              Oncology                  15
# 4             18                           Orthopedics                  17
# 5              9                      Gastroenterology                  16
# 6             17                         Ophthalmology                  14
# 7              3                Cardiovascular Disease                  20
# 8             23                     Pulmonary Disease                  14
# 9             19                             Pathology                  18
# 10            24                             Radiology                  23
# 11             6                    Emergency Medicine                  25
# 12             2                        Anesthesiology                  19
# 13            25                          Rheumatology                   8
# 14            12                HIV/Infectious Disease                  11
# 15            10                       General Surgery                  11
# 16            15                             Neurology                  12
# 17            20                            Pediatrics                  10
# 18            26                               Urology                  11
# 19            14                            Nephrology                   8
# 20             7  Endocrinology, Diabetes & Metabolism                   3
# 21             1                  Allergy & Immunology                   6
# 22             8      Family Medicine/General Practice                  10
# 23            16                                Ob/Gyn                  11
# 24             4                Critical Care Medicine                  12
# 25            13                     Internal Medicine                   9
#
#     satisfaction_score  happiness_score  pre_covid_total  post_comp_score  \
# 0                   19               23               71               25
# 1                   18               22               57               19
# 2                   17               20               56               17
# 3                   22               19               56                7
# 4                   18               21               56               22
# 5                   21               18               55               16
# 6                   15               25               54               18
# 7                   20               13               54               19
# 8                   18               19               51               15
# 9                   12               21               51               18
# 10                  14               14               51               26
# 11                  14                9               49               13
# 12                  11               16               46               11
# 13                  16               19               44               14
# 14                  13               18               42                5
# 15                  12               15               38                9
# 16                  14               10               37                9
# 17                  13               14               37                4
# 18                  14               11               37               16
# 19                   5               19               33               10
# 20                  10               19               33                5
# 21                  10               17               33               14
# 22                  10               11               32                8
# 23                   9               11               31               24
# 24                  13                6               31               11
# 25                   9                8               27                8
#
#     post_sat_score  post_hap_score  post_covid_total  total_average
# 0               27              22                74             73
# 1               24              13                56             57
# 2               16              15                48             52
# 3               18              12                38             47
# 4               29              23                75             66
# 5               22              18                56             56
# 6               24              19                61             58
# 7               18              16                53             54
# 8                5              17                38             45
# 9               11              17                46             49
# 10              21              11                58             55
# 11               9               8                31             40
# 12              15              14                40             43
# 13              14              14                42             43
# 14               2              14                21             32
# 15              12              13                34             36
# 16               6              13                28             33
# 17              11              13                28             33
# 18              19              13                48             43
# 19              15              15                41             37
# 20               6              12                24             29
# 21              12              18                44             39
# 22               3              11                22             27
# 23              23              15                62             47
# 24               7              11                29             30
# 25               3              21                33             30

# %%
main.at[22, 'specialty'] = 'General Practice'
main.at[14, 'specialty'] = 'Infectious Disease'
main.at[20, 'specialty'] = 'Endocrinology'
main.at[21, 'specialty'] = 'Immunology'
main.at[24, 'specialty'] = 'Critical Care'
main.at[7, 'specialty'] = 'Cardiovascular'
main.at[8, 'specialty'] = 'Pulmonary'
main.at[11, 'specialty'] = 'Emergency'
main
# Out:
#     specialty_id           specialty  compensation_score  satisfaction_score  \
# 0              5         Dermatology                  28                  19
# 1             21     Plastic Surgery                  17                  18
# 2             22          Psychiatry                  18                  17
# 3             11            Oncology                  15                  22
# 4             18         Orthopedics                  17                  18
# 5              9    Gastroenterology                  16                  21
# 6             17       Ophthalmology                  14                  15
# 7              3      Cardiovascular                  20                  20
# 8             23           Pulmonary                  14                  18
# 9             19           Pathology                  18                  12
# 10            24           Radiology                  23                  14
# 11             6           Emergency                  25                  14
# 12             2      Anesthesiology                  19                  11
# 13            25        Rheumatology                   8                  16
# 14            12  Infectious Disease                  11                  13
# 15            10     General Surgery                  11                  12
# 16            15           Neurology                  12                  14
# 17            20          Pediatrics                  10                  13
# 18            26             Urology                  11                  14
# 19            14          Nephrology                   8                   5
# 20             7       Endocrinology                   3                  10
# 21             1          Immunology                   6                  10
# 22             8    General Practice                  10                  10
# 23            16              Ob/Gyn                  11                   9
# 24             4       Critical Care                  12                  13
# 25            13   Internal Medicine                   9                   9
#
#     happiness_score  pre_covid_total  post_comp_score  post_sat_score  \
# 0                23               71               25              27
# 1                22               57               19              24
# 2                20               56               17              16
# 3                19               56                7              18
# 4                21               56               22              29
# 5                18               55               16              22
# 6                25               54               18              24
# 7                13               54               19              18
# 8                19               51               15               5
# 9                21               51               18              11
# 10               14               51               26              21
# 11                9               49               13               9
# 12               16               46               11              15
# 13               19               44               14              14
# 14               18               42                5               2
# 15               15               38                9              12
# 16               10               37                9               6
# 17               14               37                4              11
# 18               11               37               16              19
# 19               19               33               10              15
# 20               19               33                5               6
# 21               17               33               14              12
# 22               11               32                8               3
# 23               11               31               24              23
# 24                6               31               11               7
# 25                8               27                8               3
#
#     post_hap_score  post_covid_total  total_average
# 0               22                74             73
# 1               13                56             57
# 2               15                48             52
# 3               12                38             47
# 4               23                75             66
# 5               18                56             56
# 6               19                61             58
# 7               16                53             54
# 8               17                38             45
# 9               17                46             49
# 10              11                58             55
# 11               8                31             40
# 12              14                40             43
# 13              14                42             43
# 14              14                21             32
# 15              13                34             36
# 16              13                28             33
# 17              13                28             33
# 18              13                48             43
# 19              15                41             37
# 20              12                24             29
# 21              18                44             39
# 22              11                22             27
# 23              15                62             47
# 24              11                29             30
# 25              21                33             30

# %%
postcovid = main[['specialty_id', 'specialty', 'post_comp_score', 'post_sat_score', 
                  'post_hap_score', 'post_covid_total', 'total_average']].copy()

# %%
postcovid = postcovid.rename(columns = {'post_comp_score' : 'comp_score', 
                                        'post_sat_score' : 'sat_score',
                                        'post_hap_score' : 'hap_score',
                                        'post_covid_total' : 'total'})

# %%
postcovid.head()
# Out:
#    specialty_id        specialty  comp_score  sat_score  hap_score  total  \
# 0             5      Dermatology          25         27         22     74
# 1            21  Plastic Surgery          19         24         13     56
# 2            22       Psychiatry          17         16         15     48
# 3            11         Oncology           7         18         12     38
# 4            18      Orthopedics          22         29         23     75
#
#    total_average
# 0             73
# 1             57
# 2             52
# 3             47
# 4             66

# %%
postcovid.at[22, 'specialty'] = 'General Practice'
postcovid.at[14, 'specialty'] = 'Infectious Disease'
postcovid.at[20, 'specialty'] = 'Endocrinology'
postcovid.at[21, 'specialty'] = 'Immunology'
postcovid.at[24, 'specialty'] = 'Critical Care'
postcovid.at[7, 'specialty'] = 'Cardiovascular'
postcovid.at[8, 'specialty'] = 'Pulmonary'
postcovid.at[11, 'specialty'] = 'Emergency'
postcovid
# Out:
#     specialty_id           specialty  comp_score  sat_score  hap_score  total  \
# 0              5         Dermatology          25         27         22     74
# 1             21     Plastic Surgery          19         24         13     56
# 2             22          Psychiatry          17         16         15     48
# 3             11            Oncology           7         18         12     38
# 4             18         Orthopedics          22         29         23     75
# 5              9    Gastroenterology          16         22         18     56
# 6             17       Ophthalmology          18         24         19     61
# 7              3      Cardiovascular          19         18         16     53
# 8             23           Pulmonary          15          5         17     38
# 9             19           Pathology          18         11         17     46
# 10            24           Radiology          26         21         11     58
# 11             6           Emergency          13          9          8     31
# 12             2      Anesthesiology          11         15         14     40
# 13            25        Rheumatology          14         14         14     42
# 14            12  Infectious Disease           5          2         14     21
# 15            10     General Surgery           9         12         13     34
# 16            15           Neurology           9          6         13     28
# 17            20          Pediatrics           4         11         13     28
# 18            26             Urology          16         19         13     48
# 19            14          Nephrology          10         15         15     41
# 20             7       Endocrinology           5          6         12     24
# 21             1          Immunology          14         12         18     44
# 22             8    General Practice           8          3         11     22
# 23            16              Ob/Gyn          24         23         15     62
# 24             4       Critical Care          11          7         11     29
# 25            13   Internal Medicine           8          3         21     33
#
#     total_average
# 0              73
# 1              57
# 2              52
# 3              47
# 4              66
# 5              56
# 6              58
# 7              54
# 8              45
# 9              49
# 10             55
# 11             40
# 12             43
# 13             43
# 14             32
# 15             36
# 16             33
# 17             33
# 18             43
# 19             37
# 20             29
# 21             39
# 22             27
# 23             47
# 24             30
# 25             30

# %%
precovid = main.drop(main.iloc[:, 6:10], axis = 1)

# %%
precovid = precovid.rename(columns = {'compensation_score' : 'comp_score', 
                                        'satisfaction_score' : 'sat_score',
                                        'happiness_score' : 'hap_score',
                                        'pre_covid_total' : 'total'})

# %%
precovid.head()
# Out:
#    specialty_id        specialty  comp_score  sat_score  hap_score  total  \
# 0             5      Dermatology          28         19         23     71
# 1            21  Plastic Surgery          17         18         22     57
# 2            22       Psychiatry          18         17         20     56
# 3            11         Oncology          15         22         19     56
# 4            18      Orthopedics          17         18         21     56
#
#    total_average
# 0             73
# 1             57
# 2             52
# 3             47
# 4             66

# %%
precovid.at[22, 'specialty'] = 'General Practice'
precovid.at[14, 'specialty'] = 'Infectious Disease'
precovid.at[20, 'specialty'] = 'Endocrinology'
precovid.at[21, 'specialty'] = 'Immunology'
precovid.at[24, 'specialty'] = 'Critical Care'
precovid.at[7, 'specialty'] = 'Cardiovascular'
precovid.at[8, 'specialty'] = 'Pulmonary'
precovid.at[11, 'specialty'] = 'Emergency'
precovid
# Out:
#     specialty_id           specialty  comp_score  sat_score  hap_score  total  \
# 0              5         Dermatology          28         19         23     71
# 1             21     Plastic Surgery          17         18         22     57
# 2             22          Psychiatry          18         17         20     56
# 3             11            Oncology          15         22         19     56
# 4             18         Orthopedics          17         18         21     56
# 5              9    Gastroenterology          16         21         18     55
# 6             17       Ophthalmology          14         15         25     54
# 7              3      Cardiovascular          20         20         13     54
# 8             23           Pulmonary          14         18         19     51
# 9             19           Pathology          18         12         21     51
# 10            24           Radiology          23         14         14     51
# 11             6           Emergency          25         14          9     49
# 12             2      Anesthesiology          19         11         16     46
# 13            25        Rheumatology           8         16         19     44
# 14            12  Infectious Disease          11         13         18     42
# 15            10     General Surgery          11         12         15     38
# 16            15           Neurology          12         14         10     37
# 17            20          Pediatrics          10         13         14     37
# 18            26             Urology          11         14         11     37
# 19            14          Nephrology           8          5         19     33
# 20             7       Endocrinology           3         10         19     33
# 21             1          Immunology           6         10         17     33
# 22             8    General Practice          10         10         11     32
# 23            16              Ob/Gyn          11          9         11     31
# 24             4       Critical Care          12         13          6     31
# 25            13   Internal Medicine           9          9          8     27
#
#     total_average
# 0              73
# 1              57
# 2              52
# 3              47
# 4              66
# 5              56
# 6              58
# 7              54
# 8              45
# 9              49
# 10             55
# 11             40
# 12             43
# 13             43
# 14             32
# 15             36
# 16             33
# 17             33
# 18             43
# 19             37
# 20             29
# 21             39
# 22             27
# 23             47
# 24             30
# 25             30

# %%
avg_totals = precovid[['specialty_id', 'specialty', 'total_average']].copy()
avg_totals
# Out:
#     specialty_id           specialty  total_average
# 0              5         Dermatology             73
# 1             21     Plastic Surgery             57
# 2             22          Psychiatry             52
# 3             11            Oncology             47
# 4             18         Orthopedics             66
# 5              9    Gastroenterology             56
# 6             17       Ophthalmology             58
# 7              3      Cardiovascular             54
# 8             23           Pulmonary             45
# 9             19           Pathology             49
# 10            24           Radiology             55
# 11             6           Emergency             40
# 12             2      Anesthesiology             43
# 13            25        Rheumatology             43
# 14            12  Infectious Disease             32
# 15            10     General Surgery             36
# 16            15           Neurology             33
# 17            20          Pediatrics             33
# 18            26             Urology             43
# 19            14          Nephrology             37
# 20             7       Endocrinology             29
# 21             1          Immunology             39
# 22             8    General Practice             27
# 23            16              Ob/Gyn             47
# 24             4       Critical Care             30
# 25            13   Internal Medicine             30

# %%
avg_totals['comp_score'] = (precovid['comp_score'] + postcovid['comp_score']) / 2
avg_totals['sat_score'] = (precovid['sat_score'] + postcovid['sat_score']) / 2
avg_totals['hap_score'] = (precovid['hap_score'] + postcovid['hap_score']) / 2
avg_totals
# Out:
#     specialty_id           specialty  total_average  comp_score  sat_score  \
# 0              5         Dermatology             73        26.5       23.0
# 1             21     Plastic Surgery             57        18.0       21.0
# 2             22          Psychiatry             52        17.5       16.5
# 3             11            Oncology             47        11.0       20.0
# 4             18         Orthopedics             66        19.5       23.5
# 5              9    Gastroenterology             56        16.0       21.5
# 6             17       Ophthalmology             58        16.0       19.5
# 7              3      Cardiovascular             54        19.5       19.0
# 8             23           Pulmonary             45        14.5       11.5
# 9             19           Pathology             49        18.0       11.5
# 10            24           Radiology             55        24.5       17.5
# 11             6           Emergency             40        19.0       11.5
# 12             2      Anesthesiology             43        15.0       13.0
# 13            25        Rheumatology             43        11.0       15.0
# 14            12  Infectious Disease             32         8.0        7.5
# 15            10     General Surgery             36        10.0       12.0
# 16            15           Neurology             33        10.5       10.0
# 17            20          Pediatrics             33         7.0       12.0
# 18            26             Urology             43        13.5       16.5
# 19            14          Nephrology             37         9.0       10.0
# 20             7       Endocrinology             29         4.0        8.0
# 21             1          Immunology             39        10.0       11.0
# 22             8    General Practice             27         9.0        6.5
# 23            16              Ob/Gyn             47        17.5       16.0
# 24             4       Critical Care             30        11.5       10.0
# 25            13   Internal Medicine             30         8.5        6.0
#
#     hap_score
# 0        22.5
# 1        17.5
# 2        17.5
# 3        15.5
# 4        22.0
# 5        18.0
# 6        22.0
# 7        14.5
# 8        18.0
# 9        19.0
# 10       12.5
# 11        8.5
# 12       15.0
# 13       16.5
# 14       16.0
# 15       14.0
# 16       11.5
# 17       13.5
# 18       12.0
# 19       17.0
# 20       15.5
# 21       17.5
# 22       11.0
# 23       13.0
# 24        8.5
# 25       14.5

# %%
total_poles = pd.concat([avg_totals.sort_values('total_average', ascending=False).head().assign(dataset='top'), avg_totals.sort_values('total_average', ascending=False).tail().assign(dataset='bot')])
total_poles
# Out:
#     specialty_id           specialty  total_average  comp_score  sat_score  \
# 0              5         Dermatology             73        26.5       23.0
# 4             18         Orthopedics             66        19.5       23.5
# 6             17       Ophthalmology             58        16.0       19.5
# 1             21     Plastic Surgery             57        18.0       21.0
# 5              9    Gastroenterology             56        16.0       21.5
# 14            12  Infectious Disease             32         8.0        7.5
# 24             4       Critical Care             30        11.5       10.0
# 25            13   Internal Medicine             30         8.5        6.0
# 20             7       Endocrinology             29         4.0        8.0
# 22             8    General Practice             27         9.0        6.5
#
#     hap_score dataset
# 0        22.5     top
# 4        22.0     top
# 6        22.0     top
# 1        17.5     top
# 5        18.0     top
# 14       16.0     bot
# 24        8.5     bot
# 25       14.5     bot
# 20       15.5     bot
# 22       11.0     bot

# %%
comp_poles = pd.concat([avg_totals.sort_values('comp_score', ascending=False).head().assign(dataset='top'), avg_totals.sort_values('comp_score', ascending=False).tail().assign(dataset='bot')])
comp_poles
# Out:
#     specialty_id           specialty  total_average  comp_score  sat_score  \
# 0              5         Dermatology             73        26.5       23.0
# 10            24           Radiology             55        24.5       17.5
# 4             18         Orthopedics             66        19.5       23.5
# 7              3      Cardiovascular             54        19.5       19.0
# 11             6           Emergency             40        19.0       11.5
# 22             8    General Practice             27         9.0        6.5
# 25            13   Internal Medicine             30         8.5        6.0
# 14            12  Infectious Disease             32         8.0        7.5
# 17            20          Pediatrics             33         7.0       12.0
# 20             7       Endocrinology             29         4.0        8.0
#
#     hap_score dataset
# 0        22.5     top
# 10       12.5     top
# 4        22.0     top
# 7        14.5     top
# 11        8.5     top
# 22       11.0     bot
# 25       14.5     bot
# 14       16.0     bot
# 17       13.5     bot
# 20       15.5     bot

# %%
sat_poles = pd.concat([avg_totals.sort_values('sat_score', ascending=False).head().assign(dataset='top'), avg_totals.sort_values('sat_score', ascending=False).tail().assign(dataset='bot')])
sat_poles
# Out:
#     specialty_id           specialty  total_average  comp_score  sat_score  \
# 4             18         Orthopedics             66        19.5       23.5
# 0              5         Dermatology             73        26.5       23.0
# 5              9    Gastroenterology             56        16.0       21.5
# 1             21     Plastic Surgery             57        18.0       21.0
# 3             11            Oncology             47        11.0       20.0
# 24             4       Critical Care             30        11.5       10.0
# 20             7       Endocrinology             29         4.0        8.0
# 14            12  Infectious Disease             32         8.0        7.5
# 22             8    General Practice             27         9.0        6.5
# 25            13   Internal Medicine             30         8.5        6.0
#
#     hap_score dataset
# 4        22.0     top
# 0        22.5     top
# 5        18.0     top
# 1        17.5     top
# 3        15.5     top
# 24        8.5     bot
# 20       15.5     bot
# 14       16.0     bot
# 22       11.0     bot
# 25       14.5     bot

# %%
hap_poles = pd.concat([avg_totals.sort_values('hap_score', ascending=False).head().assign(dataset='top'), avg_totals.sort_values('hap_score', ascending=False).tail().assign(dataset='bot')])
hap_poles
# Out:
#     specialty_id         specialty  total_average  comp_score  sat_score  \
# 0              5       Dermatology             73        26.5       23.0
# 4             18       Orthopedics             66        19.5       23.5
# 6             17     Ophthalmology             58        16.0       19.5
# 9             19         Pathology             49        18.0       11.5
# 5              9  Gastroenterology             56        16.0       21.5
# 18            26           Urology             43        13.5       16.5
# 16            15         Neurology             33        10.5       10.0
# 22             8  General Practice             27         9.0        6.5
# 11             6         Emergency             40        19.0       11.5
# 24             4     Critical Care             30        11.5       10.0
#
#     hap_score dataset
# 0        22.5     top
# 4        22.0     top
# 6        22.0     top
# 9        19.0     top
# 5        18.0     top
# 18       12.0     bot
# 16       11.5     bot
# 22       11.0     bot
# 11        8.5     bot
# 24        8.5     bot

# %%
sns.set(font_scale=0.75, rc={'axes.facecolor':'lightgrey', 'figure.facecolor':'darkgrey'})

totals = sns.barplot(data=total_poles,
                   x='specialty',
                   y='total_average',
                   palette='Purples_r',
                   alpha=0.85,
                   saturation=0.8)

totals.axes.set_title("The Best & Worst Specialties", fontsize=18, pad=10)
totals.set_xlabel(None)
totals.set_ylabel('Score / 90', fontsize = 12)

totals.set_xticklabels(totals.get_xticklabels(), rotation=25, ha="right")

plt.savefig('charts/totals')
plt.show()

# %%
sns.set(font_scale=0.75, rc={'axes.facecolor':'lightgrey', 'figure.facecolor':'darkgrey'})

comp = sns.barplot(data=comp_poles,
                   x='specialty',
                   y='comp_score',
                   palette='Greens_r',
                   alpha=0.85,
                   saturation=0.8)

comp.axes.set_title("The Best & Worst Specialties - Compensation", fontsize=18, pad=10)
comp.set_xlabel(None)
comp.set_ylabel('Score / 30', fontsize = 12)

comp.set_xticklabels(comp.get_xticklabels(), rotation=25, ha="right")

plt.savefig('charts/compensation')
plt.show()

# %%
sns.set(font_scale=0.75, rc={'axes.facecolor':'lightgrey', 'figure.facecolor':'darkgrey'})

sat = sns.barplot(data=sat_poles,
                   x='specialty',
                   y='sat_score',
                   palette='Blues_r',
                   alpha=0.85,
                   saturation=0.8)

sat.axes.set_title("The Best & Worst Specialties - Satisfaction", fontsize=18, pad=10)
sat.set_xlabel(None)
sat.set_ylabel('Score / 30', fontsize = 12)

sat.set_xticklabels(sat.get_xticklabels(), rotation=25, ha="right")

plt.savefig('charts/satisfaction')
plt.show()

# %%
sns.set(font_scale=0.75, rc={'axes.facecolor':'lightgrey', 'figure.facecolor':'darkgrey'})

hap = sns.barplot(data=hap_poles,
                   x='specialty',
                   y='hap_score',
                   palette='Wistia_r',
                   alpha=0.85,
                   saturation=0.8)

hap.axes.set_title("The Best & Worst Specialties - Happiness", fontsize=18, pad=10)
hap.set_xlabel(None)
hap.set_ylabel('Score / 30', fontsize = 12)

hap.set_xticklabels(hap.get_xticklabels(), rotation=25, ha="right")

plt.savefig('charts/happiness')
plt.show()

# %%
totals2016 = pd.read_csv('../updated datasources/specialty_totals_2016.csv')
totals2018 = pd.read_csv('../updated datasources/specialty_totals_2018.csv')
totals2020 = pd.read_csv('../updated datasources/specialty_totals_2020.csv')
totals2022 = pd.read_csv('../updated datasources/specialty_totals_2022.csv')

# %%
totals2016[totals2016.columns[3]] = totals2016[totals2016.columns[3]].replace('[\$,]', 
                                                                                '', regex=True).astype(float)

# %%
totals2018[totals2018.columns[3]] = totals2018[totals2018.columns[3]].replace('[\$,]', 
                                                                                '', regex=True).astype(float)

# %%
totals2020[totals2020.columns[3]] = totals2020[totals2020.columns[3]].replace('[\$,]', 
                                                                                '', regex=True).astype(float)

# %%
totals2022[totals2022.columns[3]] = totals2022[totals2022.columns[3]].replace('[\$,]', 
                                                                                '', regex=True).astype(float)

# %%
comp_poles['salary'] = (totals2016['AVGSalary'] + totals2018['AVGSalary'] 
                        + totals2020['AVGSalary'] + totals2022['AVGSalary']) / 4

# %%
comp_poles['sat'] = (totals2016['Income Satisfaction'] + totals2018['Income Satisfaction'] 
                        + totals2020['Compensation Satisfaction'] + totals2022['Compensation Satisfaction']) / 4

# %%
comp_poles
# Out:
#     specialty_id           specialty  total_average  comp_score  sat_score  \
# 0              5         Dermatology             73        26.5       23.0
# 10            24           Radiology             55        24.5       17.5
# 4             18         Orthopedics             66        19.5       23.5
# 7              3      Cardiovascular             54        19.5       19.0
# 11             6           Emergency             40        19.0       11.5
# 22             8    General Practice             27         9.0        6.5
# 25            13   Internal Medicine             30         8.5        6.0
# 14            12  Infectious Disease             32         8.0        7.5
# 17            20          Pediatrics             33         7.0       12.0
# 20             7       Endocrinology             29         4.0        8.0
#
#     hap_score dataset    salary     sat
# 0        22.5     top  273250.0  0.5025
# 10       12.5     top  239750.0  0.5450
# 4        22.0     top  405500.0  0.6625
# 7        14.5     top  228750.0  0.5550
# 11        8.5     top  254500.0  0.5000
# 22       11.0     bot  324250.0  0.5700
# 25       14.5     bot  404500.0  0.5025
# 14       16.0     bot  318250.0  0.5100
# 17       13.5     bot  502000.0  0.5175
# 20       15.5     bot  477750.0  0.5450

# %%
total_poles
# Out:
#     specialty_id           specialty  total_average  comp_score  sat_score  \
# 0              5         Dermatology             73        26.5       23.0
# 4             18         Orthopedics             66        19.5       23.5
# 6             17       Ophthalmology             58        16.0       19.5
# 1             21     Plastic Surgery             57        18.0       21.0
# 5              9    Gastroenterology             56        16.0       21.5
# 14            12  Infectious Disease             32         8.0        7.5
# 24             4       Critical Care             30        11.5       10.0
# 25            13   Internal Medicine             30         8.5        6.0
# 20             7       Endocrinology             29         4.0        8.0
# 22             8    General Practice             27         9.0        6.5
#
#     hap_score dataset
# 0        22.5     top
# 4        22.0     top
# 6        22.0     top
# 1        17.5     top
# 5        18.0     top
# 14       16.0     bot
# 24        8.5     bot
# 25       14.5     bot
# 20       15.5     bot
# 22       11.0     bot

# %%
totals2016[totals2016.columns[2]] = totals2016[totals2016.columns[2]].replace(',', '', 
                                                                              regex=True).astype(float)

# %%
totals2018[totals2018.columns[2]] = totals2018[totals2018.columns[2]].replace(',', '', 
                                                                              regex=True).astype(float)

# %%
totals2020[totals2020.columns[2]] = totals2020[totals2020.columns[2]].replace(',', '', 
                                                                              regex=True).astype(float)

# %%
totals2022[totals2022.columns[2]] = totals2022[totals2022.columns[2]].replace(',', '', 
                                                                              regex=True).astype(float)

# %%
total_poles['Phys Count'] = (totals2016['Number of Physicans'] + totals2018['Number of Physicans']
                        + totals2020['Number of Physicans'] + totals2022['Number of Physicans']) / 4

# %%
sat_poles['Specialty Satisfaction'] = (totals2016['Specialty Satisfaction'] + totals2018['Specialty Satisfaction']
                        + totals2020['Specialty Satisfaction'] + totals2022['Specialty Satisfaction']) / 4

# %%
sat_poles
# Out:
#     specialty_id           specialty  total_average  comp_score  sat_score  \
# 4             18         Orthopedics             66        19.5       23.5
# 0              5         Dermatology             73        26.5       23.0
# 5              9    Gastroenterology             56        16.0       21.5
# 1             21     Plastic Surgery             57        18.0       21.0
# 3             11            Oncology             47        11.0       20.0
# 24             4       Critical Care             30        11.5       10.0
# 20             7       Endocrinology             29         4.0        8.0
# 14            12  Infectious Disease             32         8.0        7.5
# 22             8    General Practice             27         9.0        6.5
# 25            13   Internal Medicine             30         8.5        6.0
#
#     hap_score dataset  Specialty Satisfaction
# 4        22.0     top                  0.9075
# 0        22.5     top                  0.7625
# 5        18.0     top                  0.7250
# 1        17.5     top                  0.7700
# 3        15.5     top                  0.7175
# 24        8.5     bot                  0.7250
# 20       15.5     bot                  0.8625
# 14       16.0     bot                  0.6700
# 22       11.0     bot                  0.6950
# 25       14.5     bot                  0.8125

# %%
hap_poles['burnout'] = (totals2016['Burned Out'] + totals2018['Burned Out']
                        + totals2020['Burned Out'] + totals2022['Burned Out']) / 4

# %%
total_poles['Work Hours'] = (totals2016['Total Work Hours'] + totals2018['Total Work Hours']
                        + totals2020['Total Work Hours'] + totals2022['Total Work Hours']) / 4

# %%
total_poles
# Out:
#     specialty_id           specialty  total_average  comp_score  sat_score  \
# 0              5         Dermatology             73        26.5       23.0
# 4             18         Orthopedics             66        19.5       23.5
# 6             17       Ophthalmology             58        16.0       19.5
# 1             21     Plastic Surgery             57        18.0       21.0
# 5              9    Gastroenterology             56        16.0       21.5
# 14            12  Infectious Disease             32         8.0        7.5
# 24             4       Critical Care             30        11.5       10.0
# 25            13   Internal Medicine             30         8.5        6.0
# 20             7       Endocrinology             29         4.0        8.0
# 22             8    General Practice             27         9.0        6.5
#
#     hap_score dataset  Phys Count  Work Hours
# 0        22.5     top     4826.25      45.260
# 4        22.0     top    13915.50      43.440
# 6        22.0     top    17311.00      57.385
# 1        17.5     top    41866.75      63.560
# 5        18.0     top    33816.25      43.935
# 14       16.0     bot    42051.75      51.940
# 24        8.5     bot     6031.50      47.220
# 25       14.5     bot     9998.75      51.810
# 20       15.5     bot     7173.50      58.990
# 22       11.0     bot     5178.75      50.855

# %%
sns.set(font_scale=0.75, rc={'axes.facecolor':'lightgrey', 'figure.facecolor':'darkgrey'})

totals = sns.barplot(data=total_poles,
                   x='specialty',
                   y='Phys Count',
                   palette='Purples_r',
                   alpha=0.85,
                   saturation=0.8)

totals.axes.set_title("Count of Physicians", fontsize=18, pad=10)
totals.set_xlabel(None)
totals.set_ylabel(None)

totals.set_xticklabels(totals.get_xticklabels(), rotation=25, ha="right")

plt.savefig('charts/phys_count')
plt.show()

# %%
sns.set(font_scale=0.75, rc={'axes.facecolor':'lightgrey', 'figure.facecolor':'darkgrey'})

totals = sns.barplot(data=total_poles,
                   x='specialty',
                   y='Work Hours',
                   palette='Purples_r',
                   alpha=0.85,
                   saturation=0.8)

totals.axes.set_title("Weekly Work Hours", fontsize=18, pad=10)
totals.set_xlabel(None)
totals.set_ylabel(None)

totals.set_xticklabels(totals.get_xticklabels(), rotation=25, ha="right")

plt.savefig('charts/weekly_hours')
plt.show()

# %%
sns.set(font_scale=0.75, rc={'axes.facecolor':'lightgrey', 'figure.facecolor':'darkgrey'})

totals = sns.barplot(data=comp_poles,
                   x='specialty',
                   y='salary',
                   palette='Greens_r',
                   alpha=0.85,
                   saturation=0.8)

totals.axes.set_title("Yearly Salary", fontsize=18, pad=10)
totals.set_xlabel(None)
totals.set_ylabel(None)

totals.set_xticklabels(totals.get_xticklabels(), rotation=25, ha="right")

plt.savefig('charts/yearly_salary')
plt.show()

# %%
sns.set(font_scale=0.75, rc={'axes.facecolor':'lightgrey', 'figure.facecolor':'darkgrey'})

totals = sns.barplot(data=comp_poles,
                   x='specialty',
                   y='sat',
                   palette='Greens_r',
                   alpha=0.85,
                   saturation=0.8)

totals.axes.set_title("Compensation Satisfaction", fontsize=18, pad=10)
totals.set_xlabel(None)
totals.set_ylabel('Percent Satisfied', fontsize=10)

totals.set_xticklabels(totals.get_xticklabels(), rotation=25, ha="right")

plt.savefig('charts/comp_satisfaction')
plt.show()

# %%
sns.set(font_scale=0.75, rc={'axes.facecolor':'lightgrey', 'figure.facecolor':'darkgrey'})

sat = sns.barplot(data=sat_poles,
                   x='specialty',
                   y='Specialty Satisfaction',
                   palette='Blues_r',
                   alpha=0.85,
                   saturation=0.8)

sat.axes.set_title("Specialty Satisfaction", fontsize=18, pad=10)
sat.set_xlabel(None)
sat.set_ylabel('Percent Satisfied', fontsize = 10)

sat.set_xticklabels(sat.get_xticklabels(), rotation=25, ha="right")

plt.savefig('charts/specialty_sat')
plt.show()

# %%
sns.set(font_scale=0.75, rc={'axes.facecolor':'lightgrey', 'figure.facecolor':'darkgrey'})

hap = sns.barplot(data=hap_poles,
                   x='specialty',
                   y='burnout',
                   palette='Wistia_r',
                   alpha=0.85,
                   saturation=0.8)

hap.axes.set_title("Burnout", fontsize=18, pad=10)
hap.set_xlabel(None)
hap.set_ylabel('Percent Burned Out', fontsize = 10)

hap.set_xticklabels(hap.get_xticklabels(), rotation=25, ha="right")

plt.savefig('charts/burnout')
plt.show()

# %%
medschool_totals = pd.read_csv('../updated_datasources/medschool_totals.csv')

# %%
medschool_totals = medschool_totals.sort_values('specialty_id')

# %%
def total_cost(row):
    total_cost = 0
    ug_cost = row['undergrad'] * row['undergrad_cost']
    total_cost += ug_cost
    ms_cost = row['medschool'] * row['medschool_cost']
    total_cost += ms_cost
    r_cost = row['residency'] * row['residency_salary']
    total_cost += r_cost
    f_cost = row['fellowship'] * row['fellowship_salary']
    total_cost += f_cost
    return total_cost

# %%
medschool_totals['total_cost'] = medschool_totals.apply(total_cost, axis = 1)

# %%
medschool_totals
# Out:
#     specialty_id               specialty  undergrad_cost  undergrad  \
# 6              1    Allergy/Immunologist          -41210          4
# 18             2        Anesthesiologist          -41210          4
# 1              3              Cardiology          -41210          4
# 10             4           Critical Care          -41210          4
# 19             5           Dermatologist          -41210          4
# 22             6      Emergency Medicine          -41210          4
# 11             7           Endocrinology          -41210          4
# 25             8         Family Medicine          -41210          4
# 2              9      Gastroenterologist          -41210          4
# 3             10         General Surgery          -41210          4
# 0             11  HIV/Infectious Disease          -41210          4
# 4             12       Internal Medicine          -41210          4
# 12            13              Nephrology          -41210          4
# 13            14             Neurologist          -41210          4
# 5             15                  Ob/Gyn          -41210          4
# 20            16                Oncology          -41210          4
# 23            17           Ophthalmology          -41210          4
# 8             18             Orthopedics          -41210          4
# 15            19               Pathology          -41210          4
# 24            20            Pediatrician          -41210          4
# 14            21         Plastic Surgery          -41210          4
# 21            22              Psychiatry          -41210          4
# 9             23      Pulmonary Medicine          -41210          4
# 17            24               Radiology          -41210          4
# 7             25            Rheumatology          -41210          4
# 16            26                 Urology          -41210          4
#
#     medschool_cost  medschool  residency  residency_salary  fellowship  \
# 6           -60497          4          5             69500           2
# 18          -60497          4          5             63300           1
# 1           -60497          4          6             68600           2
# 10          -60497          4          5             66500           2
# 19          -60497          4          5             63300           1
# 22          -60497          4          5             61500           1
# 11          -60497          4          5             66500           2
# 25          -60497          4          3             58500           1
# 2           -60497          4          6             66500           2
# 3           -60497          4          6             61500           2
# 0           -60497          4          7             66500           2
# 4           -60497          4          6             61500           2
# 12          -60497          4          5             63300           2
# 13          -60497          4          5             64600           2
# 5           -60497          4          5             61500           3
# 20          -60497          4          4             66500           2
# 23          -60497          4          5             61500           1
# 8           -60497          4          6             64600           1
# 15          -60497          4          5             66500           1
# 24          -60497          4          4             63300           2
# 14          -60497          4          5             69500           1
# 21          -60497          4          5             61500           1
# 9           -60497          4          5             66500           2
# 17          -60497          4          5             64600           1
# 7           -60497          4          5             69500           2
# 16          -60497          4          5             64600           1
#
#     fellowship_salary  total_cost
# 6               48639       37950
# 18              48639      -41689
# 1               48639      102050
# 10              48639       22950
# 19              48639      -41689
# 22              48639      -50689
# 11              48639       22950
# 25              48639     -182689
# 2               48639       89450
# 3               48639       59450
# 0               48639      155950
# 4               48639       59450
# 12              48639        6950
# 13              48639       13450
# 5               48639       46589
# 20              48639      -43550
# 23              48639      -50689
# 8               48639       29411
# 15              48639      -25689
# 24              48639      -56350
# 14              48639      -10689
# 21              48639      -50689
# 9               48639       22950
# 17              48639      -35189
# 7               48639       37950
# 16              48639      -35189

# %%
medschool_totals.at[25, 'specialty'] = 'General Practice'
medschool_totals.at[0, 'specialty'] = 'Infectious Disease'
medschool_totals.at[11, 'specialty'] = 'Endocrinology'
medschool_totals.at[6, 'specialty'] = 'Immunology'
medschool_totals.at[10, 'specialty'] = 'Critical Care'
medschool_totals.at[1, 'specialty'] = 'Cardiovascular'
medschool_totals.at[9, 'specialty'] = 'Pulmonary'
medschool_totals.at[22, 'specialty'] = 'Emergency'
medschool_totals
# Out:
#     specialty_id           specialty  undergrad_cost  undergrad  \
# 6              1          Immunology          -41210          4
# 18             2    Anesthesiologist          -41210          4
# 1              3      Cardiovascular          -41210          4
# 10             4       Critical Care          -41210          4
# 19             5       Dermatologist          -41210          4
# 22             6           Emergency          -41210          4
# 11             7       Endocrinology          -41210          4
# 25             8    General Practice          -41210          4
# 2              9  Gastroenterologist          -41210          4
# 3             10     General Surgery          -41210          4
# 0             11  Infectious Disease          -41210          4
# 4             12   Internal Medicine          -41210          4
# 12            13          Nephrology          -41210          4
# 13            14         Neurologist          -41210          4
# 5             15              Ob/Gyn          -41210          4
# 20            16            Oncology          -41210          4
# 23            17       Ophthalmology          -41210          4
# 8             18         Orthopedics          -41210          4
# 15            19           Pathology          -41210          4
# 24            20        Pediatrician          -41210          4
# 14            21     Plastic Surgery          -41210          4
# 21            22          Psychiatry          -41210          4
# 9             23           Pulmonary          -41210          4
# 17            24           Radiology          -41210          4
# 7             25        Rheumatology          -41210          4
# 16            26             Urology          -41210          4
#
#     medschool_cost  medschool  residency  residency_salary  fellowship  \
# 6           -60497          4          5             69500           2
# 18          -60497          4          5             63300           1
# 1           -60497          4          6             68600           2
# 10          -60497          4          5             66500           2
# 19          -60497          4          5             63300           1
# 22          -60497          4          5             61500           1
# 11          -60497          4          5             66500           2
# 25          -60497          4          3             58500           1
# 2           -60497          4          6             66500           2
# 3           -60497          4          6             61500           2
# 0           -60497          4          7             66500           2
# 4           -60497          4          6             61500           2
# 12          -60497          4          5             63300           2
# 13          -60497          4          5             64600           2
# 5           -60497          4          5             61500           3
# 20          -60497          4          4             66500           2
# 23          -60497          4          5             61500           1
# 8           -60497          4          6             64600           1
# 15          -60497          4          5             66500           1
# 24          -60497          4          4             63300           2
# 14          -60497          4          5             69500           1
# 21          -60497          4          5             61500           1
# 9           -60497          4          5             66500           2
# 17          -60497          4          5             64600           1
# 7           -60497          4          5             69500           2
# 16          -60497          4          5             64600           1
#
#     fellowship_salary  total_cost
# 6               48639       37950
# 18              48639      -41689
# 1               48639      102050
# 10              48639       22950
# 19              48639      -41689
# 22              48639      -50689
# 11              48639       22950
# 25              48639     -182689
# 2               48639       89450
# 3               48639       59450
# 0               48639      155950
# 4               48639       59450
# 12              48639        6950
# 13              48639       13450
# 5               48639       46589
# 20              48639      -43550
# 23              48639      -50689
# 8               48639       29411
# 15              48639      -25689
# 24              48639      -56350
# 14              48639      -10689
# 21              48639      -50689
# 9               48639       22950
# 17              48639      -35189
# 7               48639       37950
# 16              48639      -35189

# %%
total_ends = pd.concat([medschool_totals.sort_values('total_cost', ascending=False).head().assign(dataset='top'), medschool_totals.sort_values('total_cost', ascending=False).tail().assign(dataset='bot')])
total_ends
# Out:
#     specialty_id           specialty  undergrad_cost  undergrad  \
# 0             11  Infectious Disease          -41210          4
# 1              3      Cardiovascular          -41210          4
# 2              9  Gastroenterologist          -41210          4
# 3             10     General Surgery          -41210          4
# 4             12   Internal Medicine          -41210          4
# 23            17       Ophthalmology          -41210          4
# 21            22          Psychiatry          -41210          4
# 22             6           Emergency          -41210          4
# 24            20        Pediatrician          -41210          4
# 25             8    General Practice          -41210          4
#
#     medschool_cost  medschool  residency  residency_salary  fellowship  \
# 0           -60497          4          7             66500           2
# 1           -60497          4          6             68600           2
# 2           -60497          4          6             66500           2
# 3           -60497          4          6             61500           2
# 4           -60497          4          6             61500           2
# 23          -60497          4          5             61500           1
# 21          -60497          4          5             61500           1
# 22          -60497          4          5             61500           1
# 24          -60497          4          4             63300           2
# 25          -60497          4          3             58500           1
#
#     fellowship_salary  total_cost dataset
# 0               48639      155950     top
# 1               48639      102050     top
# 2               48639       89450     top
# 3               48639       59450     top
# 4               48639       59450     top
# 23              48639      -50689     bot
# 21              48639      -50689     bot
# 22              48639      -50689     bot
# 24              48639      -56350     bot
# 25              48639     -182689     bot

# %%
residency_ends = pd.concat([medschool_totals.sort_values('residency', ascending=False).head().assign(dataset='top'), medschool_totals.sort_values('residency', ascending=False).tail().assign(dataset='bot')])
residency_ends
# Out:
#     specialty_id           specialty  undergrad_cost  undergrad  \
# 0             11  Infectious Disease          -41210          4
# 1              3      Cardiovascular          -41210          4
# 2              9  Gastroenterologist          -41210          4
# 3             10     General Surgery          -41210          4
# 4             12   Internal Medicine          -41210          4
# 10             4       Critical Care          -41210          4
# 16            26             Urology          -41210          4
# 20            16            Oncology          -41210          4
# 24            20        Pediatrician          -41210          4
# 25             8    General Practice          -41210          4
#
#     medschool_cost  medschool  residency  residency_salary  fellowship  \
# 0           -60497          4          7             66500           2
# 1           -60497          4          6             68600           2
# 2           -60497          4          6             66500           2
# 3           -60497          4          6             61500           2
# 4           -60497          4          6             61500           2
# 10          -60497          4          5             66500           2
# 16          -60497          4          5             64600           1
# 20          -60497          4          4             66500           2
# 24          -60497          4          4             63300           2
# 25          -60497          4          3             58500           1
#
#     fellowship_salary  total_cost dataset
# 0               48639      155950     top
# 1               48639      102050     top
# 2               48639       89450     top
# 3               48639       59450     top
# 4               48639       59450     top
# 10              48639       22950     bot
# 16              48639      -35189     bot
# 20              48639      -43550     bot
# 24              48639      -56350     bot
# 25              48639     -182689     bot

# %%
fellowship_ends = pd.concat([medschool_totals.sort_values('fellowship', ascending=False).head().assign(dataset='top'), medschool_totals.sort_values('fellowship', ascending=False).tail().assign(dataset='bot')])
fellowship_ends
# Out:
#     specialty_id           specialty  undergrad_cost  undergrad  \
# 5             15              Ob/Gyn          -41210          4
# 6              1          Immunology          -41210          4
# 0             11  Infectious Disease          -41210          4
# 7             25        Rheumatology          -41210          4
# 9             23           Pulmonary          -41210          4
# 19             5       Dermatologist          -41210          4
# 14            21     Plastic Surgery          -41210          4
# 21            22          Psychiatry          -41210          4
# 17            24           Radiology          -41210          4
# 16            26             Urology          -41210          4
#
#     medschool_cost  medschool  residency  residency_salary  fellowship  \
# 5           -60497          4          5             61500           3
# 6           -60497          4          5             69500           2
# 0           -60497          4          7             66500           2
# 7           -60497          4          5             69500           2
# 9           -60497          4          5             66500           2
# 19          -60497          4          5             63300           1
# 14          -60497          4          5             69500           1
# 21          -60497          4          5             61500           1
# 17          -60497          4          5             64600           1
# 16          -60497          4          5             64600           1
#
#     fellowship_salary  total_cost dataset
# 5               48639       46589     top
# 6               48639       37950     top
# 0               48639      155950     top
# 7               48639       37950     top
# 9               48639       22950     top
# 19              48639      -41689     bot
# 14              48639      -10689     bot
# 21              48639      -50689     bot
# 17              48639      -35189     bot
# 16              48639      -35189     bot

# %%
sns.set(font_scale=0.75, rc={'axes.facecolor':'lightgrey', 'figure.facecolor':'darkgrey'})

total_cost = sns.barplot(data=total_ends,
                   x='specialty',
                   y='total_cost',
                   palette='Purples_r',
                   alpha=0.85,
                   saturation=0.8)

total_cost.axes.set_title("The Best & Worst Specialties - Total Costs", fontsize=18, pad=10)
total_cost.set_xlabel(None)
total_cost.set_ylabel(None)

total_cost.set_xticklabels(total_cost.get_xticklabels(), rotation=25, ha="right")

for p in total_cost.patches:
    height = p.get_height()
    total_cost.text(x = p.get_x() + (p.get_width()/2),
                       y = height + height/30, s = '${:.0f}'.format(height),
                       color = 'black', ha = 'center', fontsize=8)

plt.savefig('charts/ms_total_costs')
plt.show()

# %%
sns.set(font_scale=0.75, rc={'axes.facecolor':'lightgrey', 'figure.facecolor':'darkgrey'})

residency_length = sns.barplot(data=residency_ends,
                   x='specialty',
                   y='residency',
                   palette='Reds_r',
                   alpha=0.85,
                   saturation=0.8)

residency_length.axes.set_title("The Best & Worst Specialties - Residency Length", fontsize=18, pad=10)
residency_length.set_xlabel(None)
residency_length.set_ylabel('years', fontsize=12)

residency_length.set_xticklabels(residency_length.get_xticklabels(), rotation=25, ha="right")

plt.savefig('charts/ms_residency_length')
plt.show()

# %%
sns.set(font_scale=0.75, rc={'axes.facecolor':'lightgrey', 'figure.facecolor':'darkgrey'})

fellowship_length = sns.barplot(data=fellowship_ends,
                   x='specialty',
                   y='fellowship',
                   palette='Reds_r',
                   alpha=0.85,
                   saturation=0.8)

fellowship_length.axes.set_title("The Best & Worst Specialties - Fellowship Length", fontsize=18, pad=10)
fellowship_length.set_xlabel(None)
fellowship_length.set_ylabel('years', fontsize=12)

fellowship_length.set_xticklabels(fellowship_length.get_xticklabels(), rotation=25, ha="right")

plt.savefig('charts/ms_fellowship_length')
plt.show()

# %%
doctor_salary = pd.read_csv('../original_datasources/doctor_salary.csv')

# %%
doctor_salary['total'] = (doctor_salary['2016'] + doctor_salary['2017'] + doctor_salary['2018'] + doctor_salary['2019']) / 4

# %%
doctor_salary.head()
# Out:
#    SpecialtyID             Specialty    2016    2017    2018    2019     total
# 0            1  Allergy/Immunologist  222000  257000  272000  275000  256500.0
# 1            2        Anesthesiology  360000  364000  386000  392000  375500.0
# 2            3            Cardiology  410000  410000  423000  430000  418250.0
# 3            4         Critical Care  306000  324000  354000  349000  333250.0
# 4            5           Dermatology  381000  386000  392000  419000  394500.0

# %%
doctor_salary = doctor_salary.rename({'SpecialtyID':'specialty_id'}, axis=1)

# %%
medschool_totals = pd.merge(left=medschool_totals, right=doctor_salary.iloc[:, ::6], how='left', on='specialty_id')
medschool_totals
# Out:
#     specialty_id           specialty  undergrad_cost  undergrad  \
# 0              1          Immunology          -41210          4
# 1              2    Anesthesiologist          -41210          4
# 2              3      Cardiovascular          -41210          4
# 3              4       Critical Care          -41210          4
# 4              5       Dermatologist          -41210          4
# 5              6           Emergency          -41210          4
# 6              7       Endocrinology          -41210          4
# 7              8    General Practice          -41210          4
# 8              9  Gastroenterologist          -41210          4
# 9             10     General Surgery          -41210          4
# 10            11  Infectious Disease          -41210          4
# 11            12   Internal Medicine          -41210          4
# 12            13          Nephrology          -41210          4
# 13            14         Neurologist          -41210          4
# 14            15              Ob/Gyn          -41210          4
# 15            16            Oncology          -41210          4
# 16            17       Ophthalmology          -41210          4
# 17            18         Orthopedics          -41210          4
# 18            19           Pathology          -41210          4
# 19            20        Pediatrician          -41210          4
# 20            21     Plastic Surgery          -41210          4
# 21            22          Psychiatry          -41210          4
# 22            23           Pulmonary          -41210          4
# 23            24           Radiology          -41210          4
# 24            25        Rheumatology          -41210          4
# 25            26             Urology          -41210          4
#
#     medschool_cost  medschool  residency  residency_salary  fellowship  \
# 0           -60497          4          5             69500           2
# 1           -60497          4          5             63300           1
# 2           -60497          4          6             68600           2
# 3           -60497          4          5             66500           2
# 4           -60497          4          5             63300           1
# 5           -60497          4          5             61500           1
# 6           -60497          4          5             66500           2
# 7           -60497          4          3             58500           1
# 8           -60497          4          6             66500           2
# 9           -60497          4          6             61500           2
# 10          -60497          4          7             66500           2
# 11          -60497          4          6             61500           2
# 12          -60497          4          5             63300           2
# 13          -60497          4          5             64600           2
# 14          -60497          4          5             61500           3
# 15          -60497          4          4             66500           2
# 16          -60497          4          5             61500           1
# 17          -60497          4          6             64600           1
# 18          -60497          4          5             66500           1
# 19          -60497          4          4             63300           2
# 20          -60497          4          5             69500           1
# 21          -60497          4          5             61500           1
# 22          -60497          4          5             66500           2
# 23          -60497          4          5             64600           1
# 24          -60497          4          5             69500           2
# 25          -60497          4          5             64600           1
#
#     fellowship_salary  total_cost     total
# 0               48639       37950  256500.0
# 1               48639      -41689  375500.0
# 2               48639      102050  418250.0
# 3               48639       22950  333250.0
# 4               48639      -41689  394500.0
# 5               48639      -50689  341000.0
# 6               48639       22950  218500.0
# 7               48639     -182689  216500.0
# 8               48639       89450  399000.0
# 9               48639       59450  339500.0
# 10              48639      155950  228250.0
# 11              48639       59450  230000.0
# 12              48639        6950  288000.0
# 13              48639       13450  250250.0
# 14              48639       46589  291500.0
# 15              48639      -43550  345250.0
# 16              48639      -50689  344250.0
# 17              48639       29411  477750.0
# 18              48639      -25689  288250.0
# 19              48639      -56350  210750.0
# 20              48639      -10689  441750.0
# 21              48639      -50689  248500.0
# 22              48639       22950  310750.0
# 23              48639      -35189  397750.0
# 24              48639       37950  246250.0
# 25              48639      -35189  387000.0

# %%
final = []
for row in medschool_totals.index:
    total = 0
    year_count = (medschool_totals['undergrad'][row] + medschool_totals['medschool'][row] + medschool_totals['residency'][row] + medschool_totals['fellowship'][row])
    year_dif = 20 - year_count
    output = [medschool_totals['specialty'][row]]
    for i in range(medschool_totals['undergrad'][row]):
        if year_count > 0:
            total += medschool_totals['undergrad_cost'][row]
            output.append(total)
            year_count -= 1
        else:
            output.append(total)
    for i in range(medschool_totals['medschool'][row]):
        if year_count > 0:
            total += medschool_totals['medschool_cost'][row]
            output.append(total)
            year_count -= 1
        else:
            output.append(total)
    for i in range(medschool_totals['residency'][row]):
        if year_count > 0:
            total += medschool_totals['residency_salary'][row]
            output.append(total)
            year_count -= 1
        else:
            output.append(total)
    for i in range(medschool_totals['fellowship'][row]):
        if year_count > 0:
            total += medschool_totals['fellowship_salary'][row]
            output.append(total)
            year_count -= 1
        else:
            output.append(total)
    while year_count == 0:
        if year_dif == 0:
            break
        else:
            total += medschool_totals["total"][row]
            output.append(total)
            year_dif -= 1
    final.append(output)

yearly_expenses = pd.DataFrame(final)

# %%
yearly_expenses.to_csv('../updated_datasources/yearly_expenses.csv')
yearly_expenses
# Out:
#                     0      1      2       3       4       5       6       7   \
# 0           Immunology -41210 -82420 -123630 -164840 -225337 -285834 -346331
# 1     Anesthesiologist -41210 -82420 -123630 -164840 -225337 -285834 -346331
# 2       Cardiovascular -41210 -82420 -123630 -164840 -225337 -285834 -346331
# 3        Critical Care -41210 -82420 -123630 -164840 -225337 -285834 -346331
# 4        Dermatologist -41210 -82420 -123630 -164840 -225337 -285834 -346331
# 5            Emergency -41210 -82420 -123630 -164840 -225337 -285834 -346331
# 6        Endocrinology -41210 -82420 -123630 -164840 -225337 -285834 -346331
# 7     General Practice -41210 -82420 -123630 -164840 -225337 -285834 -346331
# 8   Gastroenterologist -41210 -82420 -123630 -164840 -225337 -285834 -346331
# 9      General Surgery -41210 -82420 -123630 -164840 -225337 -285834 -346331
# 10  Infectious Disease -41210 -82420 -123630 -164840 -225337 -285834 -346331
# 11   Internal Medicine -41210 -82420 -123630 -164840 -225337 -285834 -346331
# 12          Nephrology -41210 -82420 -123630 -164840 -225337 -285834 -346331
# 13         Neurologist -41210 -82420 -123630 -164840 -225337 -285834 -346331
# 14              Ob/Gyn -41210 -82420 -123630 -164840 -225337 -285834 -346331
# 15            Oncology -41210 -82420 -123630 -164840 -225337 -285834 -346331
# 16       Ophthalmology -41210 -82420 -123630 -164840 -225337 -285834 -346331
# 17         Orthopedics -41210 -82420 -123630 -164840 -225337 -285834 -346331
# 18           Pathology -41210 -82420 -123630 -164840 -225337 -285834 -346331
# 19        Pediatrician -41210 -82420 -123630 -164840 -225337 -285834 -346331
# 20     Plastic Surgery -41210 -82420 -123630 -164840 -225337 -285834 -346331
# 21          Psychiatry -41210 -82420 -123630 -164840 -225337 -285834 -346331
# 22           Pulmonary -41210 -82420 -123630 -164840 -225337 -285834 -346331
# 23           Radiology -41210 -82420 -123630 -164840 -225337 -285834 -346331
# 24        Rheumatology -41210 -82420 -123630 -164840 -225337 -285834 -346331
# 25             Urology -41210 -82420 -123630 -164840 -225337 -285834 -346331
#
#         8       9   ...      11      12        13        14        15  \
# 0  -406828 -337328  ... -198328 -128828  -59328.0  -10689.0   37950.0
# 1  -406828 -343528  ... -216928 -153628  -90328.0  -41689.0  333811.0
# 2  -406828 -338228  ... -201028 -132428  -63828.0    4772.0   53411.0
# 3  -406828 -340328  ... -207328 -140828  -74328.0  -25689.0   22950.0
# 4  -406828 -343528  ... -216928 -153628  -90328.0  -41689.0  352811.0
# 5  -406828 -345328  ... -222328 -160828  -99328.0  -50689.0  290311.0
# 6  -406828 -340328  ... -207328 -140828  -74328.0  -25689.0   22950.0
# 7  -406828 -348328  ... -231328 -182689   33811.0  250311.0  466811.0
# 8  -406828 -340328  ... -207328 -140828  -74328.0   -7828.0   40811.0
# 9  -406828 -345328  ... -222328 -160828  -99328.0  -37828.0   10811.0
# 10 -406828 -340328  ... -207328 -140828  -74328.0   -7828.0   58672.0
# 11 -406828 -345328  ... -222328 -160828  -99328.0  -37828.0   10811.0
# 12 -406828 -343528  ... -216928 -153628  -90328.0  -41689.0    6950.0
# 13 -406828 -342228  ... -213028 -148428  -83828.0  -35189.0   13450.0
# 14 -406828 -345328  ... -222328 -160828  -99328.0  -50689.0   -2050.0
# 15 -406828 -340328  ... -207328 -140828  -92189.0  -43550.0  301700.0
# 16 -406828 -345328  ... -222328 -160828  -99328.0  -50689.0  293561.0
# 17 -406828 -342228  ... -213028 -148428  -83828.0  -19228.0   29411.0
# 18 -406828 -340328  ... -207328 -140828  -74328.0  -25689.0  262561.0
# 19 -406828 -343528  ... -216928 -153628 -104989.0  -56350.0  154400.0
# 20 -406828 -337328  ... -198328 -128828  -59328.0  -10689.0  431061.0
# 21 -406828 -345328  ... -222328 -160828  -99328.0  -50689.0  197811.0
# 22 -406828 -340328  ... -207328 -140828  -74328.0  -25689.0   22950.0
# 23 -406828 -342228  ... -213028 -148428  -83828.0  -35189.0  362561.0
# 24 -406828 -337328  ... -198328 -128828  -59328.0  -10689.0   37950.0
# 25 -406828 -342228  ... -213028 -148428  -83828.0  -35189.0  351811.0
#
#           16         17         18         19         20
# 0   294450.0   550950.0   807450.0  1063950.0  1320450.0
# 1   709311.0  1084811.0  1460311.0  1835811.0  2211311.0
# 2   102050.0   520300.0   938550.0  1356800.0  1775050.0
# 3   356200.0   689450.0  1022700.0  1355950.0  1689200.0
# 4   747311.0  1141811.0  1536311.0  1930811.0  2325311.0
# 5   631311.0   972311.0  1313311.0  1654311.0  1995311.0
# 6   241450.0   459950.0   678450.0   896950.0  1115450.0
# 7   683311.0   899811.0  1116311.0  1332811.0  1549311.0
# 8    89450.0   488450.0   887450.0  1286450.0  1685450.0
# 9    59450.0   398950.0   738450.0  1077950.0  1417450.0
# 10  107311.0   155950.0   384200.0   612450.0   840700.0
# 11   59450.0   289450.0   519450.0   749450.0   979450.0
# 12  294950.0   582950.0   870950.0  1158950.0  1446950.0
# 13  263700.0   513950.0   764200.0  1014450.0  1264700.0
# 14   46589.0   338089.0   629589.0   921089.0  1212589.0
# 15  646950.0   992200.0  1337450.0  1682700.0  2027950.0
# 16  637811.0   982061.0  1326311.0  1670561.0  2014811.0
# 17  507161.0   984911.0  1462661.0  1940411.0  2418161.0
# 18  550811.0   839061.0  1127311.0  1415561.0  1703811.0
# 19  365150.0   575900.0   786650.0   997400.0  1208150.0
# 20  872811.0  1314561.0  1756311.0  2198061.0  2639811.0
# 21  446311.0   694811.0   943311.0  1191811.0  1440311.0
# 22  333700.0   644450.0   955200.0  1265950.0  1576700.0
# 23  760311.0  1158061.0  1555811.0  1953561.0  2351311.0
# 24  284200.0   530450.0   776700.0  1022950.0  1269200.0
# 25  738811.0  1125811.0  1512811.0  1899811.0  2286811.0
#
# [26 rows x 21 columns]

# %%
T_yearly_expenses = yearly_expenses.transpose()

# %%
T_yearly_expenses.columns = T_yearly_expenses.iloc[0]

# %%
T_yearly_expenses = T_yearly_expenses.tail(-1)

# %%
T_yearly_expenses['year'] = [i for i in range(1, 21)]

# %%
T_yearly_expenses.to_csv('../updated_datasources/t_yearly_expenses.csv')
T_yearly_expenses
# Out:
# 0  Immunology Anesthesiologist Cardiovascular Critical Care Dermatologist  \
# 1      -41210           -41210         -41210        -41210        -41210
# 2      -82420           -82420         -82420        -82420        -82420
# 3     -123630          -123630        -123630       -123630       -123630
# 4     -164840          -164840        -164840       -164840       -164840
# 5     -225337          -225337        -225337       -225337       -225337
# 6     -285834          -285834        -285834       -285834       -285834
# 7     -346331          -346331        -346331       -346331       -346331
# 8     -406828          -406828        -406828       -406828       -406828
# 9     -337328          -343528        -338228       -340328       -343528
# 10    -267828          -280228        -269628       -273828       -280228
# 11    -198328          -216928        -201028       -207328       -216928
# 12    -128828          -153628        -132428       -140828       -153628
# 13   -59328.0         -90328.0       -63828.0      -74328.0      -90328.0
# 14   -10689.0         -41689.0         4772.0      -25689.0      -41689.0
# 15    37950.0         333811.0        53411.0       22950.0      352811.0
# 16   294450.0         709311.0       102050.0      356200.0      747311.0
# 17   550950.0        1084811.0       520300.0      689450.0     1141811.0
# 18   807450.0        1460311.0       938550.0     1022700.0     1536311.0
# 19  1063950.0        1835811.0      1356800.0     1355950.0     1930811.0
# 20  1320450.0        2211311.0      1775050.0     1689200.0     2325311.0
#
# 0   Emergency Endocrinology General Practice Gastroenterologist  \
# 1      -41210        -41210           -41210             -41210
# 2      -82420        -82420           -82420             -82420
# 3     -123630       -123630          -123630            -123630
# 4     -164840       -164840          -164840            -164840
# 5     -225337       -225337          -225337            -225337
# 6     -285834       -285834          -285834            -285834
# 7     -346331       -346331          -346331            -346331
# 8     -406828       -406828          -406828            -406828
# 9     -345328       -340328          -348328            -340328
# 10    -283828       -273828          -289828            -273828
# 11    -222328       -207328          -231328            -207328
# 12    -160828       -140828          -182689            -140828
# 13   -99328.0      -74328.0          33811.0           -74328.0
# 14   -50689.0      -25689.0         250311.0            -7828.0
# 15   290311.0       22950.0         466811.0            40811.0
# 16   631311.0      241450.0         683311.0            89450.0
# 17   972311.0      459950.0         899811.0           488450.0
# 18  1313311.0      678450.0        1116311.0           887450.0
# 19  1654311.0      896950.0        1332811.0          1286450.0
# 20  1995311.0     1115450.0        1549311.0          1685450.0
#
# 0  General Surgery  ... Orthopedics  Pathology Pediatrician Plastic Surgery  \
# 1           -41210  ...      -41210     -41210       -41210          -41210
# 2           -82420  ...      -82420     -82420       -82420          -82420
# 3          -123630  ...     -123630    -123630      -123630         -123630
# 4          -164840  ...     -164840    -164840      -164840         -164840
# 5          -225337  ...     -225337    -225337      -225337         -225337
# 6          -285834  ...     -285834    -285834      -285834         -285834
# 7          -346331  ...     -346331    -346331      -346331         -346331
# 8          -406828  ...     -406828    -406828      -406828         -406828
# 9          -345328  ...     -342228    -340328      -343528         -337328
# 10         -283828  ...     -277628    -273828      -280228         -267828
# 11         -222328  ...     -213028    -207328      -216928         -198328
# 12         -160828  ...     -148428    -140828      -153628         -128828
# 13        -99328.0  ...    -83828.0   -74328.0    -104989.0        -59328.0
# 14        -37828.0  ...    -19228.0   -25689.0     -56350.0        -10689.0
# 15         10811.0  ...     29411.0   262561.0     154400.0        431061.0
# 16         59450.0  ...    507161.0   550811.0     365150.0        872811.0
# 17        398950.0  ...    984911.0   839061.0     575900.0       1314561.0
# 18        738450.0  ...   1462661.0  1127311.0     786650.0       1756311.0
# 19       1077950.0  ...   1940411.0  1415561.0     997400.0       2198061.0
# 20       1417450.0  ...   2418161.0  1703811.0    1208150.0       2639811.0
#
# 0  Psychiatry  Pulmonary  Radiology Rheumatology    Urology year
# 1      -41210     -41210     -41210       -41210     -41210    1
# 2      -82420     -82420     -82420       -82420     -82420    2
# 3     -123630    -123630    -123630      -123630    -123630    3
# 4     -164840    -164840    -164840      -164840    -164840    4
# 5     -225337    -225337    -225337      -225337    -225337    5
# 6     -285834    -285834    -285834      -285834    -285834    6
# 7     -346331    -346331    -346331      -346331    -346331    7
# 8     -406828    -406828    -406828      -406828    -406828    8
# 9     -345328    -340328    -342228      -337328    -342228    9
# 10    -283828    -273828    -277628      -267828    -277628   10
# 11    -222328    -207328    -213028      -198328    -213028   11
# 12    -160828    -140828    -148428      -128828    -148428   12
# 13   -99328.0   -74328.0   -83828.0     -59328.0   -83828.0   13
# 14   -50689.0   -25689.0   -35189.0     -10689.0   -35189.0   14
# 15   197811.0    22950.0   362561.0      37950.0   351811.0   15
# 16   446311.0   333700.0   760311.0     284200.0   738811.0   16
# 17   694811.0   644450.0  1158061.0     530450.0  1125811.0   17
# 18   943311.0   955200.0  1555811.0     776700.0  1512811.0   18
# 19  1191811.0  1265950.0  1953561.0    1022950.0  1899811.0   19
# 20  1440311.0  1576700.0  2351311.0    1269200.0  2286811.0   20
#
# [20 rows x 27 columns]

# %%
lineplot = sns.relplot(data=T_yearly_expenses.tail(5), legend=False, linewidth=1.5, kind='line')

lineplot.fig.suptitle("Year over Year Costs", fontsize=15)
lineplot.set(xlabel=None, ylabel=None);

plt.savefig('charts/ms_yoy_costs')

# %%
medschool_totals['cost_score'] = round(medschool_totals['total_cost'].rank(pct=True), 2)

# %%
medschool_totals

# %%
final_conclusion = pd.merge(left=main, right=medschool_totals, how='left', on='specialty_id')

# %%
final_conclusion.columns

# %%
sns.set(font_scale=0.9, rc={'axes.facecolor':'lightgrey', 'figure.facecolor':'darkgrey'}, )

final = sns.relplot(data=final_conclusion,
                   x='cost_score',
                   y='total_average',
                   s=75,
                   hue='total_average',
                   palette='Blues',
                   legend=False)

final.set(xlabel='Medschool Score', ylabel='Specialty Score')

plt.title("Putting it All Together", fontsize=18, pad=10)

output1 = []
for i in final_conclusion.sort_values('cost_score', ascending=False).head(4).itertuples():
    output1.append(i[2])
    
for j in output1:
    plt.text(x=final_conclusion.cost_score[final_conclusion['specialty_x']==j] + 0.03,
         y=final_conclusion.total_average[final_conclusion['specialty_x']==j] + 1.25,
         s=j,
         fontdict=dict(color='lightblue', size=10),
         bbox=dict(facecolor='darkblue', alpha=0.85))  

output2 = []
for i in final_conclusion.sort_values('total_average', ascending=False).head(4).itertuples():
    output2.append(i[2])
    
for j in output2:
    plt.text(x=final_conclusion.cost_score[final_conclusion['specialty_x']==j] + 0.03,
         y=final_conclusion.total_average[final_conclusion['specialty_x']==j] + 1.25,
         s=j,
         fontdict=dict(color='lightblue', size=10),
         bbox=dict(facecolor='darkblue', alpha=0.85))     

plt.savefig('charts/ms_final_conclusion')
plt.show()
